# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
location = "datasets/FinalNewData.xlsx"
df = pd.read_excel(location)
dfnew = df.dropna()
dfnew.head(1)
# Out:
#    Year NATIONALITY  RECEIVED  GRANTED  DENIED  ABANDONED  WITHDRAWN  OTHER
# 0  2016       CHINA      1574     3103     590        318        252   3425

# %%
Topdata = dfsort.head(10)
Topdata
# Out:
#      Year  NATIONALITY  RECEIVED  GRANTED  DENIED  ABANDONED  WITHDRAWN  OTHER
# 729  2016  EL SALVADOR     17709      753    2415        307        529   4210
# 715  2016       MEXICO     12831      464    2624        453       2615   4766
# 726  2016    GUATEMALA     11354      632    1475        307        523   2949
# 725  2016     HONDURAS     10818      620    1917        302        309   2247
# 701  2016        INDIA      1840      309     201         31         81    729
# 0    2016        CHINA      1574     3103     590        318        252   3425
# 4    2016      ECUADOR      1042       43      81         31        391    770
# 684  2016        GHANA       524       65     195          5         12     55
# 30   2016      SOMALIA       456      153     355          0         18     33
# 20   2016        NEPAL       434      265      66          8         20    212

# %%
export_excel = Topdata.to_excel (r'datasets\ImmigratioTopData.xlsx', index = None, header=True)

# %%
loc='datasets\ImmigratioTopData.xlsx'
savedtop= pd.read_excel(loc)
savedtop
# Out:
#    Year  NATIONALITY  RECEIVED  GRANTED  DENIED  ABANDONED  WITHDRAWN  OTHER
# 0  2016  EL SALVADOR     17709      753    2415        307        529   4210
# 1  2016       MEXICO     12831      464    2624        453       2615   4766
# 2  2016    GUATEMALA     11354      632    1475        307        523   2949
# 3  2016     HONDURAS     10818      620    1917        302        309   2247
# 4  2016        INDIA      1840      309     201         31         81    729
# 5  2016        CHINA      1574     3103     590        318        252   3425
# 6  2016      ECUADOR      1042       43      81         31        391    770
# 7  2016        GHANA       524       65     195          5         12     55
# 8  2016      SOMALIA       456      153     355          0         18     33
# 9  2016        NEPAL       434      265      66          8         20    212

# %%
sns.lmplot(x='RECEIVED', y='DENIED', data=Topdata, 
           fit_reg=True, #remove regression line
           hue='NATIONALITY')   #color by evolution stage

# %%
sns.distplot(Topdata['RECEIVED'])
